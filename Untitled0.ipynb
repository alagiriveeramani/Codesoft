# %%
def chatbot(user_input):
    rules = {
        "hello": "Hi! How can I assist you today?",
        "hi": "Hello! What's on your mind?",
        "how are you": "I'm doing well, thanks! How about you?",
        "what's your name": "I'm a simple chatbot, nice to meet you!",
        "quit": "Goodbye! It was nice chatting with you."
    }

    user_input = user_input.lower()

    for rule, response in rules.items():
        if rule in user_input:
            return response

    return "I didn't understand that. Can you please rephrase?"

while True:
    user_input = input("You: ")
    response = chatbot(user_input)
    print("Chatbot:", response)
    if user_input.lower() == "quit":
        break
# Out:
# Chatbot: Hello! What's on your mind?
